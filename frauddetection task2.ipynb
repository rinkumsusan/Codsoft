# %%
import numpy as np
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
train_df=pd.read_csv('Downloads/fraud/fraudTrain.csv')

# %%
train_df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
# 2           2   2019-01-01 00:00:51    38859492057661
# 3           3   2019-01-01 00:01:16  3534093764340240
# 4           4   2019-01-01 00:03:06   375534208663984
#
#                              merchant       category     amt      first  \
# 0          fraud_Rippin, Kub and Mann       misc_net    4.97   Jennifer
# 1     fraud_Heller, Gutmann and Zieme    grocery_pos  107.23  Stephanie
# 2                fraud_Lind-Buckridge  entertainment  220.11     Edward
# 3  fraud_Kutch, Hermiston and Farrell  gas_transport   45.00     Jeremy
# 4                 fraud_Keeling-Crist       misc_pos   41.96      Tyler
#
#       last gender                        street  ...      lat      long  \
# 0    Banks      F                561 Perry Cove  ...  36.0788  -81.1781
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296675 entries, 0 to 1296674
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   Unnamed: 0             1296675 non-null  int64
#  1   trans_date_trans_time  1296675 non-null  object
#  2   cc_num                 1296675 non-null  int64
#  3   merchant               1296675 non-null  object
#  4   category               1296675 non-null  object
#  5   amt                    1296675 non-null  float64
#  6   first                  1296675 non-null  object
#  7   last                   1296675 non-null  object
#  8   gender                 1296675 non-null  object
#  9   street                 1296675 non-null  object
#  10  city                   1296675 non-null  object
#  11  state                  1296675 non-null  object
#  12  zip                    1296675 non-null  int64
#  13  lat                    1296675 non-null  float64
# ...

# %%
missing_values=train_df.isnull().sum()

# %%
print(missing_values)
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
duplicated=train_df.duplicated()

# %%
print("Duplicate Rows in the Dataset:")
print(train_df[duplicated])
# Out:
# Duplicate Rows in the Dataset:
# Empty DataFrame
# Columns: [Unnamed: 0, trans_date_trans_time, cc_num, merchant, category, amt, first, last, gender, street, city, state, zip, lat, long, city_pop, job, dob, trans_num, unix_time, merch_lat, merch_long, is_fraud]
# Index: []
#
# [0 rows x 23 columns]

# %%
train_df.tail()
# Out:
#          Unnamed: 0 trans_date_trans_time               cc_num  \
# 1296670     1296670   2020-06-21 12:12:08       30263540414123
# 1296671     1296671   2020-06-21 12:12:19     6011149206456997
# 1296672     1296672   2020-06-21 12:12:32     3514865930894695
# 1296673     1296673   2020-06-21 12:13:36     2720012583106919
# 1296674     1296674   2020-06-21 12:13:37  4292902571056973207
#
#                                     merchant       category     amt  \
# 1296670                    fraud_Reichel Inc  entertainment   15.56
# 1296671             fraud_Abernathy and Sons    food_dining   51.70
# 1296672                 fraud_Stiedemann Ltd    food_dining  105.93
# 1296673  fraud_Reinger, Weissnat and Strosin    food_dining   74.90
# 1296674  fraud_Langosh, Wintheiser and Hyatt    food_dining    4.30
#
#                first       last gender                         street  ...  \
# 1296670         Erik  Patterson      M       162 Jessica Row Apt. 072  ...
# ...

# %%
train_df.is_fraud.value_counts()
# Out:
# is_fraud
# 0    1289169
# 1       7506
# Name: count, dtype: int64

# %%
train_df.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean   6.483370e+05  4.171920e+17  7.035104e+01  4.880067e+04  3.853762e+01
# std    3.743180e+05  1.308806e+18  1.603160e+02  2.689322e+04  5.075808e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    3.241685e+05  1.800429e+14  9.650000e+00  2.623700e+04  3.462050e+01
# 50%    6.483370e+05  3.521417e+15  4.752000e+01  4.817400e+04  3.935430e+01
# 75%    9.725055e+05  4.642255e+15  8.314000e+01  7.204200e+04  4.194040e+01
# max    1.296674e+06  4.992346e+18  2.894890e+04  9.978300e+04  6.669330e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06  1.296675e+06
# mean  -9.022634e+01  8.882444e+04  1.349244e+09  3.853734e+01 -9.022646e+01
# ...

# %%
train_df['trans_date_trans_time'] = pd.to_datetime(train_df['trans_date_trans_time'])

# Convert 'dob' to datetime
train_df['dob'] = pd.to_datetime(train_df['dob'])

# Extract useful features from transaction date
train_df['Transaction_Year'] = train_df['trans_date_trans_time'].dt.year
train_df['Transaction_Month'] = train_df['trans_date_trans_time'].dt.month
train_df['Transaction_Day'] = train_df['trans_date_trans_time'].dt.day
train_df['Transaction_Hour'] = train_df['trans_date_trans_time'].dt.hour
train_df['Transaction_Weekday'] = train_df['trans_date_trans_time'].dt.weekday  # 0 = Monday, 6 = Sunday

# Convert 'dob' to 'Age' (More useful than raw DOB)
train_df['Age'] =train_df['dob'].apply(lambda x: 2025 - x.year)  # Assuming analysis is in 2025

# Drop original datetime columns (optional, if not needed)
train_df = train_df.drop(columns=['trans_date_trans_time', 'dob'])

# Save preprocessed dataset (optional)
train_df.to_csv("preprocessed_data.csv", index=False)

# %%
x_train = train_df.drop(columns=['is_fraud'])  # Drop target column
y_train = train_df['is_fraud']

# %%
print(x_train.dtypes)  # Check data types
print(x_train.head())  # View first few rows
# Out:
# Unnamed: 0               int64
# cc_num                   int64
# merchant                object
# category                object
# amt                    float64
# first                   object
# last                    object
# gender                  object
# street                  object
# city                    object
# state                   object
# zip                      int64
# lat                    float64
# long                   float64
# city_pop                 int64
# job                     object
# trans_num               object
# unix_time                int64
# merch_lat              float64
# merch_long             float64
# Transaction_Year         int32
# Transaction_Month        int32
# Transaction_Day          int32
# Transaction_Hour         int32
# Transaction_Weekday      int32
# Age                      int64
# dtype: object
#    Unnamed: 0            cc_num                            merchant  \
# ...

# %%
x_train = x_train.drop(columns=['merchant','unix_time','Unnamed: 0','cc_num','merchant','first','last','street','zip','trans_num','city'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 x_train = x_train.drop(columns=['merchant','unix_time','Unnamed: 0','cc_num','merchant','first','last','street','zip','trans_num','city'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
# ...

# %%
x_train.head()

# %%
x_train.gender=x_train.gender.apply(lambda x: 1 if x=="M" else 0)
x_train.gender.value_counts()
x_train.head()

# %%
x_train = x_train.drop(columns=['job','merch_lat','merch_long','long','lat'])

#for col in train_df.select_dtypes(include=['object']).columns:
#    train_df[col] = train_df[col].astype('category')

# %%
x_train.head()
# Out:
#         category     amt  gender state  city_pop  Transaction_Year  \
# 0       misc_net    4.97       0    NC      3495              2019
# 1    grocery_pos  107.23       0    WA       149              2019
# 2  entertainment  220.11       1    ID      4154              2019
# 3  gas_transport   45.00       1    MT      1939              2019
# 4       misc_pos   41.96       1    VA        99              2019
#
#    Transaction_Month  Transaction_Day  Transaction_Hour  Transaction_Weekday  \
# 0                  1                1                 0                    1
# 1                  1                1                 0                    1
# 2                  1                1                 0                    1
# 3                  1                1                 0                    1
# 4                  1                1                 0                    1
#
#    Age
# 0   37
# 1   47
# 2   63
# 3   58
# 4   39

# %%
x_train = pd.get_dummies(x_train, columns=['category'], drop_first=True)

#x_train = x_train.astype({col: 'float32' for col in df.select_dtypes(include=['float64']).columns})

# %%
x_train.head()
# Out:
#       amt  gender state  city_pop  Transaction_Year  Transaction_Month  \
# 0    4.97       0    NC      3495              2019                  1
# 1  107.23       0    WA       149              2019                  1
# 2  220.11       1    ID      4154              2019                  1
# 3   45.00       1    MT      1939              2019                  1
# 4   41.96       1    VA        99              2019                  1
#
#    Transaction_Day  Transaction_Hour  Transaction_Weekday  Age  ...  \
# 0                1                 0                    1   37  ...
# 1                1                 0                    1   47  ...
# 2                1                 0                    1   63  ...
# 3                1                 0                    1   58  ...
# 4                1                 0                    1   39  ...
#
#    category_grocery_pos  category_health_fitness  category_home  \
# ...

# %%
x_train=x_train.drop(columns=['state'])

# %%
x_train.head()
# Out:
#       amt  gender  city_pop  Transaction_Year  Transaction_Month  \
# 0    4.97       0      3495              2019                  1
# 1  107.23       0       149              2019                  1
# 2  220.11       1      4154              2019                  1
# 3   45.00       1      1939              2019                  1
# 4   41.96       1        99              2019                  1
#
#    Transaction_Day  Transaction_Hour  Transaction_Weekday  Age  \
# 0                1                 0                    1   37
# 1                1                 0                    1   47
# 2                1                 0                    1   63
# 3                1                 0                    1   58
# 4                1                 0                    1   39
#
#    category_food_dining  ...  category_grocery_pos  category_health_fitness  \
# 0                 False  ...                 False                    False
# ...

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
print("Scaling completed successfully!")
# Out:
# Scaling completed successfully!

# %%
model = LogisticRegression()
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_train_pred = model.predict(x_train_scaled)

# %%
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f"Training Accuracy: {train_accuracy:.2f}")
print("\nClassification Report (Training Data):\n", classification_report(y_train, y_train_pred))
print("\nConfusion Matrix (Training Data):\n", confusion_matrix(y_train, y_train_pred))
# Out:
# Training Accuracy: 0.99
#
# Classification Report (Training Data):
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00   1289169
#            1       0.13      0.01      0.02      7506
#
#     accuracy                           0.99   1296675
#    macro avg       0.56      0.51      0.51   1296675
# weighted avg       0.99      0.99      0.99   1296675
#
#
# Confusion Matrix (Training Data):
#  [[1288606     563]
#  [   7419      87]]

# %%
testdf=pd.read_csv('Downloads/fraud/fraudTest.csv')

# %%
testdf.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
testdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555719 entries, 0 to 555718
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             555719 non-null  int64
#  1   trans_date_trans_time  555719 non-null  object
#  2   cc_num                 555719 non-null  int64
#  3   merchant               555719 non-null  object
#  4   category               555719 non-null  object
#  5   amt                    555719 non-null  float64
#  6   first                  555719 non-null  object
#  7   last                   555719 non-null  object
#  8   gender                 555719 non-null  object
#  9   street                 555719 non-null  object
#  10  city                   555719 non-null  object
#  11  state                  555719 non-null  object
#  12  zip                    555719 non-null  int64
#  13  lat                    555719 non-null  float64
# ...

# %%
missing_value=testdf.isnull().sum()

# %%
print(missing_value)
# Out:
# Unnamed: 0               0
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
testdf['trans_date_trans_time'] = pd.to_datetime(testdf['trans_date_trans_time'])

# Convert 'dob' to datetime
testdf['dob'] = pd.to_datetime(testdf['dob'])

# Extract useful features from transaction date
testdf['Transaction_Year'] = testdf['trans_date_trans_time'].dt.year
testdf['Transaction_Month'] = testdf['trans_date_trans_time'].dt.month
testdf['Transaction_Day'] = testdf['trans_date_trans_time'].dt.day
testdf['Transaction_Hour'] = testdf['trans_date_trans_time'].dt.hour
testdf['Transaction_Weekday'] = testdf['trans_date_trans_time'].dt.weekday  # 0 = Monday, 6 = Sunday

# Convert 'dob' to 'Age' (More useful than raw DOB)
testdf['Age'] =testdf['dob'].apply(lambda x: 2025 - x.year)  # Assuming analysis is in 2025

# Drop original datetime columns (optional, if not needed)
testdf = testdf.drop(columns=['trans_date_trans_time', 'dob'])

# Save preprocessed dataset (optional)
testdf.to_csv("preprocessed_data1.csv", index=False)

# %%
testdf.head()
# Out:
#    Unnamed: 0            cc_num                              merchant  \
# 0           0  2291163933867244                 fraud_Kirlin and Sons
# 1           1  3573030041201292                  fraud_Sporer-Keebler
# 2           2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch
# 3           3  3591919803438423                     fraud_Haley Group
# 4           4  3526826139003047                 fraud_Johnston-Casper
#
#          category    amt   first      last gender  \
# 0   personal_care   2.86    Jeff   Elliott      M
# 1   personal_care  29.84  Joanne  Williams      F
# 2  health_fitness  41.28  Ashley     Lopez      F
# 3        misc_pos  60.05   Brian  Williams      M
# 4          travel   3.19  Nathan    Massey      M
#
#                         street        city  ...   unix_time  merch_lat  \
# 0            351 Darlene Green    Columbia  ...  1371816865  33.986391
# 1             3638 Marsh Union     Altonah  ...  1371816873  39.450498
# ...

# %%
my=pd.read_csv('preprocessed_data1.csv')

# %%
my.head()
# Out:
#    Unnamed: 0            cc_num                              merchant  \
# 0           0  2291163933867244                 fraud_Kirlin and Sons
# 1           1  3573030041201292                  fraud_Sporer-Keebler
# 2           2  3598215285024754  fraud_Swaniawski, Nitzsche and Welch
# 3           3  3591919803438423                     fraud_Haley Group
# 4           4  3526826139003047                 fraud_Johnston-Casper
#
#          category    amt   first      last gender  \
# 0   personal_care   2.86    Jeff   Elliott      M
# 1   personal_care  29.84  Joanne  Williams      F
# 2  health_fitness  41.28  Ashley     Lopez      F
# 3        misc_pos  60.05   Brian  Williams      M
# 4          travel   3.19  Nathan    Massey      M
#
#                         street        city  ...   unix_time  merch_lat  \
# 0            351 Darlene Green    Columbia  ...  1371816865  33.986391
# 1             3638 Marsh Union     Altonah  ...  1371816873  39.450498
# ...

# %%
x_test = testdf.drop(columns=['is_fraud'])  # Drop target column
y_test = testdf['is_fraud']

# %%
print(x_test.dtypes)  # Check data types
print(x_test.head())  # View first few rows
# Out:
# Unnamed: 0               int64
# cc_num                   int64
# merchant                object
# category                object
# amt                    float64
# first                   object
# last                    object
# gender                  object
# street                  object
# city                    object
# state                   object
# zip                      int64
# lat                    float64
# long                   float64
# city_pop                 int64
# job                     object
# trans_num               object
# unix_time                int64
# merch_lat              float64
# merch_long             float64
# Transaction_Year         int32
# Transaction_Month        int32
# Transaction_Day          int32
# Transaction_Hour         int32
# Transaction_Weekday      int32
# Age                      int64
# dtype: object
#    Unnamed: 0            cc_num                              merchant  \
# ...

# %%
x_test = x_test.drop(columns=['merchant','unix_time','Unnamed: 0','cc_num','merchant','first','last','street','zip','trans_num','city'])

# %%
x_test.head()
# Out:
#          category    amt gender state      lat      long  city_pop  \
# 0   personal_care   2.86      M    SC  33.9659  -80.9355    333497
# 1   personal_care  29.84      F    UT  40.3207 -110.4360       302
# 2  health_fitness  41.28      F    NY  40.6729  -73.5365     34496
# 3        misc_pos  60.05      M    FL  28.5697  -80.8191     54767
# 4          travel   3.19      M    MI  44.2529  -85.0170      1126
#
#                       job  merch_lat  merch_long  Transaction_Year  \
# 0     Mechanical engineer  33.986391  -81.200714              2020
# 1  Sales professional, IT  39.450498 -109.960431              2020
# 2       Librarian, public  40.495810  -74.196111              2020
# 3            Set designer  28.812398  -80.883061              2020
# 4      Furniture designer  44.959148  -85.884734              2020
#
#    Transaction_Month  Transaction_Day  Transaction_Hour  Transaction_Weekday  \
# 0                  6               21                12                    6
# ...

# %%
x_test=x_test.drop(columns=['state'])

# %%
x_test.head()
# Out:
#          category    amt gender      lat      long  city_pop  \
# 0   personal_care   2.86      M  33.9659  -80.9355    333497
# 1   personal_care  29.84      F  40.3207 -110.4360       302
# 2  health_fitness  41.28      F  40.6729  -73.5365     34496
# 3        misc_pos  60.05      M  28.5697  -80.8191     54767
# 4          travel   3.19      M  44.2529  -85.0170      1126
#
#                       job  merch_lat  merch_long  Transaction_Year  \
# 0     Mechanical engineer  33.986391  -81.200714              2020
# 1  Sales professional, IT  39.450498 -109.960431              2020
# 2       Librarian, public  40.495810  -74.196111              2020
# 3            Set designer  28.812398  -80.883061              2020
# 4      Furniture designer  44.959148  -85.884734              2020
#
#    Transaction_Month  Transaction_Day  Transaction_Hour  Transaction_Weekday  \
# 0                  6               21                12                    6
# ...

# %%
x_test = pd.get_dummies(x_test, columns=['category'], drop_first=True)

# %%
x_test.gender=x_test.gender.apply(lambda x: 1 if x=="M" else 0)
x_test.gender.value_counts()
x_test.head()
# Out:
#      amt  gender      lat      long  city_pop                     job  \
# 0   2.86       1  33.9659  -80.9355    333497     Mechanical engineer
# 1  29.84       0  40.3207 -110.4360       302  Sales professional, IT
# 2  41.28       0  40.6729  -73.5365     34496       Librarian, public
# 3  60.05       1  28.5697  -80.8191     54767            Set designer
# 4   3.19       1  44.2529  -85.0170      1126      Furniture designer
#
#    merch_lat  merch_long  Transaction_Year  Transaction_Month  ...  \
# 0  33.986391  -81.200714              2020                  6  ...
# 1  39.450498 -109.960431              2020                  6  ...
# 2  40.495810  -74.196111              2020                  6  ...
# 3  28.812398  -80.883061              2020                  6  ...
# 4  44.959148  -85.884734              2020                  6  ...
#
#    category_grocery_pos  category_health_fitness  category_home  \
# 0                 False                    False          False
# ...

# %%
x_test = x_test.drop(columns=['job','merch_lat','merch_long','long','lat'])

# %%
scaler = StandardScaler()
x_test_scaled = scaler.fit_transform(x_test)
print("Scaling completed successfully!")
# Out:
# Scaling completed successfully!

# %%
model = LogisticRegression()
model.fit(x_test_scaled, y_test)
# Out:
# LogisticRegression()

# %%
y_test_pred = model.predict(x_test_scaled)

# %%
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Testing Accuracy: {test_accuracy:.2f}")
print("\nClassification Report (Testing Data):\n", classification_report(y_test, y_test_pred))
print("\nConfusion Matrix (Testing Data):\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Testing Accuracy: 1.00
#
# Classification Report (Testing Data):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.00      0.00      0.00      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.50      0.50      0.50    555719
# weighted avg       0.99      1.00      0.99    555719
#
#
# Confusion Matrix (Testing Data):
#  [[553431    143]
#  [  2145      0]]

# %% [markdown]
# Decision Tree

# %%
model1 = DecisionTreeClassifier(max_depth=5, random_state=42)  # You can tune max_depth
#model = DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5, random_state=42)

model1.fit(x_train_scaled, y_train)

# **Predictions on Training Data**
y_train_pred = model1.predict(x_train_scaled)

# **Evaluation on Training Data**
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f"Training Accuracy: {train_accuracy:.2f}")
print("\nClassification Report (Training Data):\n", classification_report(y_train, y_train_pred))
print("\nConfusion Matrix (Training Data):\n", confusion_matrix(y_train, y_train_pred))
# Out:
# Training Accuracy: 1.00
#
# Classification Report (Training Data):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   1289169
#            1       0.95      0.59      0.73      7506
#
#     accuracy                           1.00   1296675
#    macro avg       0.97      0.79      0.86   1296675
# weighted avg       1.00      1.00      1.00   1296675
#
#
# Confusion Matrix (Training Data):
#  [[1288927     242]
#  [   3098    4408]]

# %%
model1 = DecisionTreeClassifier(max_depth=5, random_state=42)  
#model = DecisionTreeClassifier(max_depth=5, min_samples_split=10, min_samples_leaf=5, random_state=42)

model1.fit(x_test_scaled, y_test)


y_test_pred = model.predict(x_test_scaled)


test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"Testisng Accuracy: {test_accuracy:.2f}")
print("\nClassification Report (Testing Data):\n", classification_report(y_test, y_test_pred))
print("\nConfusion Matrix (Testing Data):\n", confusion_matrix(y_test, y_test_pred))
# Out:
# Testisng Accuracy: 1.00
#
# Classification Report (Testing Data):
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    553574
#            1       0.00      0.00      0.00      2145
#
#     accuracy                           1.00    555719
#    macro avg       0.50      0.50      0.50    555719
# weighted avg       0.99      1.00      0.99    555719
#
#
# Confusion Matrix (Testing Data):
#  [[553431    143]
#  [  2145      0]]
